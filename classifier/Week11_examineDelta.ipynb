# %% [markdown]
# Again, just cause the other notebooks are getting crowded, I'm making a new one to carry on. Examining the delta data with a few new ideas;
# 1. to look at the differeneces in decays of 1114 and -2214 (i.e. why are these labeled as different things? seems redundant!)
# 2. see what different types of deltas tend to decay into

# %%
#imports
import uproot as ur
import numpy as np
import awkward as ak
import matplotlib.pyplot as plt
import vector as v

data_path = '/fast_scratch/atlas_images/v01-45/'

import atlas_mpl_style as ampl #makes matplotlib follow atlas formal style
ampl.use_atlas_style()

v.register_awkward()

# %%
branches = ['cluster_hitsTruthIndex', 'cluster_hitsTruthE', 'truthPartPdgId', 'truthPartPt','truthPartEta', 
            'truthPartPhi', 'truthPartPt', 'truthPartMass']

events = ur.open(data_path+'delta_medium.root')

tree = events['EventTree']

# %%
the_branches = tree.arrays(expressions=branches)

# %%
truthE = the_branches.cluster_hitsTruthE
truthEIndex = the_branches.cluster_hitsTruthIndex
truthID = the_branches.truthPartPdgId
trutheta = the_branches.truthPartEta
truthphi = the_branches.truthPartPhi
truthpt = the_branches.truthPartPt
truthmass = the_branches.truthPartMass

# %%
ID1114 = []
phi1114 = []
eta1114 = []
pt1114 = []
m1114 = []

IDn2214 = []
phin2214 = []
etan2214 = []
ptn2214 = []
mn2214 = []

for i in range(len(truthID)):
    
    if (1114 in truthID[i]): 
        ID1114.append(truthID[i])
        phi1114.append(truthphi[i])
        eta1114.append(trutheta[i])
        pt1114.append(truthpt[i])
        m1114.append(truthmass[i])
    elif (-2214 in truthID[i]):
        IDn2214.append(truthID[i])
        phin2214.append(truthphi[i])
        etan2214.append(trutheta[i])
        ptn2214.append(truthpt[i])
        mn2214.append(truthmass[i])

# %%
ID1114
# Out:
# [<Array [1114, 2112, -211] type='3 * int32'>,
#  <Array [1114, 2112, -211] type='3 * int32'>,
#  <Array [1114, 2112, -211] type='3 * int32'>,
#  <Array [1114, 2112, -211] type='3 * int32'>,
#  <Array [1114, 2112, -211] type='3 * int32'>,
#  <Array [1114, 2112, -211] type='3 * int32'>,
#  <Array [1114, 2112, -211] type='3 * int32'>,
#  <Array [1114, 2112, -211] type='3 * int32'>,
#  <Array [1114, 2112, -211] type='3 * int32'>,
#  <Array [1114, 2112, -211] type='3 * int32'>,
#  <Array [1114, 2112, -211, 22, 22] type='5 * int32'>,
#  <Array [1114, 2112, -211] type='3 * int32'>,
#  <Array [1114, 2112, -211] type='3 * int32'>,
#  <Array [1114, 2112, -211] type='3 * int32'>,
#  <Array [1114, 2112, -211] type='3 * int32'>,
#  <Array [1114, 2112, -211, 22] type='4 * int32'>,
#  <Array [1114, 2112, -211] type='3 * int32'>,
#  <Array [1114, 2112, -211] type='3 * int32'>,
#  <Array [1114, 2112, -211] type='3 * int32'>,
#  <Array [1114, 2112, -211] type='3 * int32'>,
# ...

# %%
#quick plots of both:
ID1114_aspd = ak.to_pandas(ak.flatten(ID1114))
IDn2214_aspd = ak.to_pandas(ak.flatten(IDn2214))

# %%
plt.figure(figsize=[7,7])
ID1114_aspd.value_counts().plot(kind='bar', color='xkcd:dark gold')
plt.text(2.2,20000, '-211 = $\pi^-$ \n 22 = $\gamma$\n 1114 = $\Delta^-$\n 2112 = neutron\n')
# Out:
# Text(2.2, 20000, '-211 = $\\pi^-$ \n 22 = $\\gamma$\n 1114 = $\\Delta^-$\n 2112 = neutron\n')

# %%
plt.figure(figsize=[7,7])
IDn2214_aspd.value_counts().plot(kind='bar', color='xkcd:bland')
plt.text(4,15000, '-2214 = anti-$\Delta^+$\n -2212 = antiproton\n -2112 = antineutron\n -211 = $\pi^-$ \n -11 = positron\n 11 = elecron\n 22 = $\gamma$\n 111 = $\pi^0$\n')
# Out:
# Text(4, 15000, '-2214 = anti-$\\Delta^+$\n -2212 = antiproton\n -2112 = antineutron\n -211 = $\\pi^-$ \n -11 = positron\n 11 = elecron\n 22 = $\\gamma$\n 111 = $\\pi^0$\n')

# %%
#examine the other deltas the same way:
IDn2114 = []
phin2114 = []
etan2114 = []
ptn2114 = []
mn2114 = []

IDn2224 = []
phin2224 = []
etan2224 = []
ptn2224 = []
mn2224 = []

ID2214 = []
phi2214 = []
eta2214 = []
pt2214 = []
m2214 = []

ID2224 = []
phi2224 = []
eta2224 = []
pt2224 = []
m2224 = []

IDn1114 = []
phin1114 = []
etan1114 = []
ptn1114 = []
mn1114 = []

ID2114 = []
phi2114 = []
eta2114 = []
pt2114 = []
m2114 = []

for i in range(len(truthID)):
    
    if (-2114 in truthID[i]): 
        IDn2114.append(truthID[i])
        phin2114.append(truthphi[i])
        etan2114.append(trutheta[i])
        ptn2114.append(truthpt[i])
        mn2114.append(truthmass[i])
    elif (-2224 in truthID[i]):
        IDn2224.append(truthID[i])
        phin2224.append(truthphi[i])
        etan2224.append(trutheta[i])
        ptn2224.append(truthpt[i])
        mn2224.append(truthmass[i])
    elif (2214 in truthID[i]): 
        ID2214.append(truthID[i])
        phi2214.append(truthphi[i])
        eta2214.append(trutheta[i])
        pt2214.append(truthpt[i])
        m2214.append(truthmass[i])
    elif (2224 in truthID[i]):
        ID2224.append(truthID[i])
        phi2224.append(truthphi[i])
        eta2224.append(trutheta[i])
        pt2224.append(truthpt[i])
        m2224.append(truthmass[i])
    elif (-1114 in truthID[i]): 
        IDn1114.append(truthID[i])
        phin1114.append(truthphi[i])
        etan1114.append(trutheta[i])
        ptn1114.append(truthpt[i])
        mn1114.append(truthmass[i])
    elif (2114 in truthID[i]):
        ID2114.append(truthID[i])
        phi2114.append(truthphi[i])
        eta2114.append(trutheta[i])
        pt2114.append(truthpt[i])
        m2114.append(truthmass[i])

# %%
IDn2114_aspd = ak.to_pandas(ak.flatten(IDn2114))
IDn2224_aspd = ak.to_pandas(ak.flatten(IDn2224))
ID2214_aspd = ak.to_pandas(ak.flatten(ID2214))
ID2224_aspd = ak.to_pandas(ak.flatten(ID2224))
IDn1114_aspd = ak.to_pandas(ak.flatten(IDn1114))
ID2114_aspd = ak.to_pandas(ak.flatten(ID2114))

# %%
plt.figure(figsize=[7,7])
IDn2114_aspd.value_counts().plot(kind='bar', color='xkcd:yellow tan')
plt.text(4,15000, '-2212 = antiproton\n -2114 = anti-$\Delta^0$\n -2112 = antineutron\n -11 = positron\n 11 = elecron\n 22 = $\gamma$\n 111 = $\pi^0$\n 211 = $pi^+$\n')
# Out:
# Text(4, 15000, '-2212 = antiproton\n -2114 = anti-$\\Delta^0$\n -2112 = antineutron\n -11 = positron\n 11 = elecron\n 22 = $\\gamma$\n 111 = $\\pi^0$\n 211 = $pi^+$\n')

# %%
plt.figure(figsize=[7,7])
IDn2224_aspd.value_counts().plot(kind='bar', color='xkcd:yellow brown')
plt.text(2.2,13000, '-2224 = anti-$\Delta^{++}$\n-2212 = antiproton\n-211 = $\pi^-$ (?)\n22 = $\gamma$')
# Out:
# Text(2.2, 13000, '-2224 = anti-$\\Delta^{++}$\n-2212 = antiproton\n-211 = $\\pi^-$ (?)\n22 = $\\gamma$')

# %%
plt.figure(figsize=[7,7])
ID2214_aspd.value_counts().plot(kind='bar', color='xkcd:sandy')
plt.text(4,15000, '-11 = positron\n 11 = elecron\n 22 = $\gamma$\n 111 = $\pi^0$\n 211 = $pi^+$\n 2112 = neutron\n 2212 = proton\n 2214 = $\Delta^+$')
# Out:
# Text(4, 15000, '-11 = positron\n 11 = elecron\n 22 = $\\gamma$\n 111 = $\\pi^0$\n 211 = $pi^+$\n 2112 = neutron\n 2212 = proton\n 2214 = $\\Delta^+$')

# %%
plt.figure(figsize=[7,7])
ID2224_aspd.value_counts().plot(kind='bar', color='xkcd:light gold')
plt.text(2.2,13000, ' 22 = $\gamma$\n 211 = $pi^+$\n 2212 = proton\n 2224 = $\Delta^{++}$')
# Out:
# Text(2.2, 13000, ' 22 = $\\gamma$\n 211 = $pi^+$\n 2212 = proton\n 2224 = $\\Delta^{++}$')

# %%
plt.figure(figsize=[7,7])
IDn1114_aspd.value_counts().plot(kind='bar', color='xkcd:dark mustard')
plt.text(2.2,13000, ' -2112 = antineutron\n -1114 = anti-$\Delta^-$\n 22 = $\gamma$\n 211 = $pi^+$')
# Out:
# Text(2.2, 13000, ' -2112 = antineutron\n -1114 = anti-$\\Delta^-$\n 22 = $\\gamma$\n 211 = $pi^+$')

# %%
plt.figure(figsize=[7,7])
ID2114_aspd.value_counts().plot(kind='bar', color='xkcd:gold')
plt.text(4,15000, ' -211 = $\pi^-$\n -11 = positron\n 11 = elecron\n 22 = $\gamma$\n 111 = $\pi^0$\n 2112 = neutron\n 2114 = $\Delta^0$\n 2212 = proton')
# Out:
# Text(4, 15000, ' -211 = $\\pi^-$\n -11 = positron\n 11 = elecron\n 22 = $\\gamma$\n 111 = $\\pi^0$\n 2112 = neutron\n 2114 = $\\Delta^0$\n 2212 = proton')

# %% [markdown]
# #### So the above was just to make clear that yeah, delta- and - delta+ are not the same thing; the four delta particles are delta++, delta+, delta0, and delta-, and then each of these has a corresponding antiparticle comprised of anti-quarks instead of quarks, so that's probably what all the negative IDs are. so my labelling was correct!
