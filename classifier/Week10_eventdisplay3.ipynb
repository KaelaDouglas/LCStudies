# %% [markdown]
# Just gonna make this one a bit cleaner, throw things into more functions, so all I'll have to do is just try it all on different events

# %%
import Week10_eventdisp_utils as ed

# %%
event, geo, track, idx = ed.loadup('pipm_small.root')

# %%
ed.run(event, geo, track, idx)
# Out:
# All events, shape (160000,)
# Single Track Indices, shape (97242,)
# Central track indices, shape (30820,)
# Central tracks with matched clusters, shape (24496,)
# Options:  [1, 2, 3, 4, 5, 7, 16, 38, 40, 70, 92, 97, 107, 116, 124, 155, 160, 177, 179, 185, 190, 197, 204, 210, 211, 212, 220, 237, 246, 257]
# Choose one of the above: 204
# Number of Clusters: 1
# Number in each:
# 318
# Number of tracks: 1

# %%
ed.run(event, geo, track, idx)
# Out:
# All events, shape (160000,)
# Single Track Indices, shape (97242,)
# Central track indices, shape (30820,)
# Central tracks with matched clusters, shape (24496,)
# Options:  [1, 2, 3, 4, 5, 7, 16, 38, 40, 70, 92, 97, 107, 116, 124, 155, 160, 177, 179, 185, 190, 197, 204, 210, 211, 212, 220, 237, 246, 257]
# Choose one of the above: 160
# Number of Clusters: 1
# Number in each:
# 154
# Number of tracks: 1

# %%
ed.run(event, geo, track, idx)
# Out:
# All events, shape (160000,)
# Single Track Indices, shape (97242,)
# Central track indices, shape (30820,)
# Central tracks with matched clusters, shape (24496,)
# Options:  [1, 2, 3, 4, 5, 7, 16, 38, 40, 70, 92, 97, 107, 116, 124, 155, 160, 177, 179, 185, 190, 197, 204, 210, 211, 212, 220, 237, 246, 257]
# Choose one of the above: 4
# Number of Clusters: 2
# Number of cells in each Cluster:
# 57
# 7
# Number of tracks: 1

# %%
ed.run(event, geo, track, idx)
# Out:
# All events, shape (160000,)
# Single Track Indices, shape (97242,)
# Central track indices, shape (30820,)
# Central tracks with matched clusters, shape (24496,)
# Options:  [1, 2, 3, 4, 5, 7, 16, 38, 40, 70, 92, 97, 107, 116, 124, 155, 160, 177, 179, 185, 190, 197, 204, 210, 211, 212, 220, 237, 246, 257]
# Choose one of the above: 92
# Number of Clusters: 1
# Number in each:
# 79
# Number of tracks: 1

# %%
event0, geo0, track0, idx0 = ed.loadup('pi0_medium.root')

# %%
ed.run(event0, geo0, track0, idx0)
# Out:
# All events, shape (400000,)
# Single Track Indices, shape (14502,)
# Central track indices, shape (2455,)
# Central tracks with matched clusters, shape (2160,)
# Options:  [443, 651, 686, 888, 1225, 1438, 1471, 1475, 1484, 1523, 1687, 1818, 1873, 1924, 2092, 2348, 2498, 2560, 2620, 2868, 3238, 3983, 4283, 4341, 4421, 4755, 4792, 5544, 5797, 6007]
# Choose one of the above: 888
# Number of Clusters: 2
# Number in each:
# 23
# 20
# Number of tracks: 1

# %%
ed.run(event0, geo0, track0, idx0)
# Out:
# All events, shape (400000,)
# Single Track Indices, shape (14502,)
# Central track indices, shape (2455,)
# Central tracks with matched clusters, shape (2160,)
# Options:  [443, 651, 686, 888, 1225, 1438, 1471, 1475, 1484, 1523, 1687, 1818, 1873, 1924, 2092, 2348, 2498, 2560, 2620, 2868, 3238, 3983, 4283, 4341, 4421, 4755, 4792, 5544, 5797, 6007]
# Choose one of the above: 6007
# Number of Clusters: 3
# Number in each:
# 34
# 30
# 20
# Number of tracks: 1
# /home/kaelaekd/start_tf/LCStudies/classifier/Week10_eventdisp_utils.py:83: RuntimeWarning: overflow encountered in exp
#   _theta = 2*np.arctan( np.exp(-_eta) )

# %%
ed.run(event0, geo0, track0, idx0)
# Out:
# All events, shape (400000,)
# Single Track Indices, shape (14502,)
# Central track indices, shape (2455,)
# Central tracks with matched clusters, shape (2160,)
# Options:  [443, 651, 686, 888, 1225, 1438, 1471, 1475, 1484, 1523, 1687, 1818, 1873, 1924, 2092, 2348, 2498, 2560, 2620, 2868, 3238, 3983, 4283, 4341, 4421, 4755, 4792, 5544, 5797, 6007]
# Choose one of the above: 1818
# Number of Clusters: 2
# Number in each:
# 55
# 13
# Number of tracks: 1
# /home/kaelaekd/start_tf/LCStudies/classifier/Week10_eventdisp_utils.py:83: RuntimeWarning: overflow encountered in exp
#   _theta = 2*np.arctan( np.exp(-_eta) )

# %%
ed.run(event0, geo0, track0, idx0)
# Out:
# All events, shape (400000,)
# Single Track Indices, shape (14502,)
# Central track indices, shape (2455,)
# Central tracks with matched clusters, shape (2160,)
# Options:  [443, 651, 686, 888, 1225, 1438, 1471, 1475, 1484, 1523, 1687, 1818, 1873, 1924, 2092, 2348, 2498, 2560, 2620, 2868, 3238, 3983, 4283, 4341, 4421, 4755, 4792, 5544, 5797, 6007]
# Choose one of the above: 4283
# Number of Clusters: 3
# Number in each:
# 37
# 33
# 4
# Number of tracks: 1

# %%
eventr, geor, trackr, idxr = ed.loadup('rho_medium.root')

# %%
ed.run(eventr, geor, trackr, idxr)
# Out:
# All events, shape (400000,)
# Single Track Indices, shape (269169,)
# Central track indices, shape (85239,)
# Central tracks with matched clusters, shape (73206,)
# Options:  [1, 2, 16, 21, 38, 39, 42, 44, 45, 47, 52, 61, 63, 67, 70, 78, 87, 92, 93, 98, 103, 106, 107, 110, 116, 117, 121, 123, 124, 130]
# Choose one of the above: 16
# Number of Clusters: 2
# Number in each:
# 108
# 55
# Number of tracks: 1

# %%
ed.run(eventr, geor, trackr, idxr)
# Out:
# All events, shape (400000,)
# Single Track Indices, shape (269169,)
# Central track indices, shape (85239,)
# Central tracks with matched clusters, shape (73206,)
# Options:  [1, 2, 16, 21, 38, 39, 42, 44, 45, 47, 52, 61, 63, 67, 70, 78, 87, 92, 93, 98, 103, 106, 107, 110, 116, 117, 121, 123, 124, 130]
# Choose one of the above: 52
# Number of Clusters: 2
# Number in each:
# 73
# 13
# Number of tracks: 1

# %%
ed.run(eventr, geor, trackr, idxr)
# Out:
# All events, shape (400000,)
# Single Track Indices, shape (269169,)
# Central track indices, shape (85239,)
# Central tracks with matched clusters, shape (73206,)
# Options:  [1, 2, 16, 21, 38, 39, 42, 44, 45, 47, 52, 61, 63, 67, 70, 78, 87, 92, 93, 98, 103, 106, 107, 110, 116, 117, 121, 123, 124, 130]
# Choose one of the above: 1
# Number of Clusters: 4
# Number of cells in each Cluster:
# 124
# 137
# 12
# 9
# Number of tracks: 1

# %%
ed.run(eventr, geor, trackr, idxr)
# Out:
# All events, shape (400000,)
# Single Track Indices, shape (269169,)
# Central track indices, shape (85239,)
# Central tracks with matched clusters, shape (73206,)
# Options:  [1, 2, 16, 21, 38, 39, 42, 44, 45, 47, 52, 61, 63, 67, 70, 78, 87, 92, 93, 98, 103, 106, 107, 110, 116, 117, 121, 123, 124, 130]
# Choose one of the above: 2
# Number of Clusters: 9
# Number of cells in each Cluster:
# 383
# 110
# 18
# 4
# 6
# 10
# 2
# 8
# 2
# Number of tracks: 1

# %%
ed.run(eventr, geor, trackr, idxr)
# Out:
# All events, shape (400000,)
# Single Track Indices, shape (269169,)
# Central track indices, shape (85239,)
# Central tracks with matched clusters, shape (73206,)
# Options:  [1, 2, 16, 21, 38, 39, 42, 44, 45, 47, 52, 61, 63, 67, 70, 78, 87, 92, 93, 98, 103, 106, 107, 110, 116, 117, 121, 123, 124, 130]
# Choose one of the above: 98
# Number of Clusters: 2
# Number in each:
# 142
# 32
# Number of tracks: 1

# %%
ed.run(eventr, geor, trackr, idxr)
# Out:
# All events, shape (400000,)
# Single Track Indices, shape (269169,)
# Central track indices, shape (85239,)
# Central tracks with matched clusters, shape (73206,)
# Options:  [1, 2, 16, 21, 38, 39, 42, 44, 45, 47, 52, 61, 63, 67, 70, 78, 87, 92, 93, 98, 103, 106, 107, 110, 116, 117, 121, 123, 124, 130]
# Choose one of the above: 117
# Number of Clusters: 4
# Number in each:
# 114
# 21
# 4
# 4
# Number of tracks: 1

# %%
ed.run(eventr, geor, trackr, idxr)
# Out:
# All events, shape (400000,)
# Single Track Indices, shape (269169,)
# Central track indices, shape (85239,)
# Central tracks with matched clusters, shape (73206,)
# Options:  [1, 2, 16, 21, 38, 39, 42, 44, 45, 47, 52, 61, 63, 67, 70, 78, 87, 92, 93, 98, 103, 106, 107, 110, 116, 117, 121, 123, 124, 130]
# Choose one of the above: 39
# Number of Clusters: 5
# Number in each:
# 435
# 8
# 6
# 7
# 5
# Number of tracks: 1

# %%
eventd, geod, trackd, idxd = ed.loadup('delta_medium.root')

# %%
ed.run(eventd, geod, trackd, idxd)
# Out:
# All events, shape (200000,)
# Single Track Indices, shape (87138,)
# Central track indices, shape (25037,)
# Central tracks with matched clusters, shape (21083,)
# Options:  [15, 17, 19, 22, 27, 45, 46, 56, 62, 67, 79, 86, 92, 98, 105, 115, 117, 121, 182, 191, 197, 214, 216, 224, 227, 235, 242, 259, 261, 263]
# Choose one of the above: 22
# Number of Clusters: 6
# Number of cells in each Cluster:
# 91
# 49
# 58
# 3
# 8
# 5
# Number of tracks: 1

# %%
ed.run(eventd, geod, trackd, idxd)
# Out:
# All events, shape (200000,)
# Single Track Indices, shape (87138,)
# Central track indices, shape (25037,)
# Central tracks with matched clusters, shape (21083,)
# Options:  [15, 17, 19, 22, 27, 45, 46, 56, 62, 67, 79, 86, 92, 98, 105, 115, 117, 121, 182, 191, 197, 214, 216, 224, 227, 235, 242, 259, 261, 263]
# Choose one of the above: 182
# Number of Clusters: 4
# Number in each:
# 400
# 85
# 8
# 10
# Number of tracks: 1

# %%
ed.run(eventd, geod, trackd, idxd)
# Out:
# All events, shape (200000,)
# Single Track Indices, shape (87138,)
# Central track indices, shape (25037,)
# Central tracks with matched clusters, shape (21083,)
# Options:  [15, 17, 19, 22, 27, 45, 46, 56, 62, 67, 79, 86, 92, 98, 105, 115, 117, 121, 182, 191, 197, 214, 216, 224, 227, 235, 242, 259, 261, 263]
# Choose one of the above: 46
# Number of Clusters: 2
# Number in each:
# 36
# 7
# Number of tracks: 1

# %%
ed.run(eventd, geod, trackd, idxd)
# Out:
# All events, shape (200000,)
# Single Track Indices, shape (87138,)
# Central track indices, shape (25037,)
# Central tracks with matched clusters, shape (21083,)
# Options:  [15, 17, 19, 22, 27, 45, 46, 56, 62, 67, 79, 86, 92, 98, 105, 115, 117, 121, 182, 191, 197, 214, 216, 224, 227, 235, 242, 259, 261, 263]
# Choose one of the above: 105
# Number of Clusters: 1
# Number in each:
# 37
# Number of tracks: 1

# %%
ed.run(eventd, geod, trackd, idxd)
# Out:
# All events, shape (200000,)
# Single Track Indices, shape (87138,)
# Central track indices, shape (25037,)
# Central tracks with matched clusters, shape (21083,)
# Options:  [15, 17, 19, 22, 27, 45, 46, 56, 62, 67, 79, 86, 92, 98, 105, 115, 117, 121, 182, 191, 197, 214, 216, 224, 227, 235, 242, 259, 261, 263]
# Choose one of the above: 224
# Number of Clusters: 2
# Number in each:
# 157
# 123
# Number of tracks: 1
